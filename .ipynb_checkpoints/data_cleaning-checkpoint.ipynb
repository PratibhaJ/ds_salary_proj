# %%
import pandas as pd

# %%
df = pd.read_csv('glassdoor_jobs.csv')

# %%
df.shape
# Out:
# (956, 16)

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# ..          ...           ...
# 951         951           951
# 952         952           952
# 953         953           953
# 954         954           954
# 955         955           955
#
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# ...

# %%
#tasks:
# salary parsing
#Company name text only
# state field
#age of company
#parsing of job description(like keyword:Python)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors'],
#       dtype='object')

# %% [markdown]
# ### Salary Parsing

# %% [raw]
# There exist the following values as well in the salary estimate field/dataframe
#     - Employer Provided Salary:$150K-$160K
#     - $17-$24 Per Hour
#     - -1

# %%
df['hourly'] = df['Salary Estimate'].apply(lambda x : 1 if 'per hour' in x.lower() else 0)

# %%
df['employer_provided'] = df['Salary Estimate'].apply(lambda x : 1 if 'employer provided salary:' in x.lower() else 0)

# %%
df = df[df['Salary Estimate'] != '-1']

# %%
df.shape
# Out:
# (742, 18)

# %%
# remove text part of salary estimate field
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])

# %%
salary.head()
# Out:
# 0     $53K-$91K
# 1    $63K-$112K
# 2     $80K-$90K
# 3     $56K-$97K
# 4    $86K-$143K
# Name: Salary Estimate, dtype: object

# %%
# remove 'k','$','-' characters from salary field
# minus k and dollar symbol
minus_kd = salary.apply(lambda x: x.replace('K','').replace('$',''))

# %%
minus_kd.head()
# Out:
# 0     53-91
# 1    63-112
# 2     80-90
# 3     56-97
# 4    86-143
# Name: Salary Estimate, dtype: object

# %%
min_hr = minus_kd.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))

# %%
# 53-91 , min and max salary save differently
df['min_salary'] = min_hr.apply(lambda x : x.split('-')[0])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1                  Job Title  \
# 0           0             0             Data Scientist
# 1           1             1  Healthcare Data Scientist
#
#                Salary Estimate  \
# 0   $53K-$91K (Glassdoor est.)
# 1  $63K-$112K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
#
#                                  Company Name         Location   Headquarters  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
#
#                     Size  Founded   Type of ownership  \
# 0  501 to 1000 employees     1973   Company - Private
# 1       10000+ employees     1984  Other Organization
#
#                            Industry               Sector  \
# ...

# %%
df['max_salary'] = min_hr.apply(lambda x : x.split('-')[1])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1                  Job Title  \
# 0           0             0             Data Scientist
# 1           1             1  Healthcare Data Scientist
#
#                Salary Estimate  \
# 0   $53K-$91K (Glassdoor est.)
# 1  $63K-$112K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
#
#                                  Company Name         Location   Headquarters  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
#
#                     Size  Founded   Type of ownership  \
# 0  501 to 1000 employees     1973   Company - Private
# 1       10000+ employees     1984  Other Organization
#
#                            Industry               Sector  \
# ...

# %%
# with min and max salary values we can calculate average salary
cols = ['min_salary','max_salary']
df['avg_salary'] = df[cols].astype(float).mean(axis=1)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1                  Job Title  \
# 0           0             0             Data Scientist
# 1           1             1  Healthcare Data Scientist
#
#                Salary Estimate  \
# 0   $53K-$91K (Glassdoor est.)
# 1  $63K-$112K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
#
#                                  Company Name         Location   Headquarters  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
#
#                     Size  ...   Type of ownership  \
# 0  501 to 1000 employees  ...   Company - Private
# 1       10000+ employees  ...  Other Organization
#
#                            Industry               Sector  \
# ...

# %% [markdown]
# ### Company name text only

# %%
df['company_txt'] = df.apply(lambda x : x['Company Name'] if x['Rating']<0 else x['Company Name'][:-3], axis=1)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1                  Job Title  \
# 0           0             0             Data Scientist
# 1           1             1  Healthcare Data Scientist
#
#                Salary Estimate  \
# 0   $53K-$91K (Glassdoor est.)
# 1  $63K-$112K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
#
#                                  Company Name         Location   Headquarters  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
#
#                     Size  ...                          Industry  \
# 0  501 to 1000 employees  ...               Aerospace & Defense
# 1       10000+ employees  ...  Health Care Services & Hospitals
#
#                 Sector                    Revenue Competitors hourly  \
# ...

# %% [markdown]
# ### State Field

# %%
# df['job_state'] = df['Location'].apply(lambda x: x.split(',')[0])
df['job_state'] = df['Location'].apply(lambda x: x.split(',')[1])
df.job_state.value_counts()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  CA             151
#  MA             103
#  NY              72
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  NC              21
#  WA              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  DC              11
#  CO              11
#  UT              10
#  IN              10
#  WI              10
#  MO               9
#  AZ               9
#  AL               8
#  KY               6
#  GA               6
#  MI               6
#  DE               6
#  CT               5
#  IA               5
#  OR               4
# ...

# %%
df.job_state.value_counts()
# Out:
#  CA             151
#  MA             103
#  NY              72
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  NC              21
#  WA              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  DC              11
#  CO              11
#  UT              10
#  IN              10
#  WI              10
#  MO               9
#  AZ               9
#  AL               8
#  KY               6
#  GA               6
#  MI               6
#  DE               6
#  CT               5
#  IA               5
#  OR               4
#  NE               4
#  LA               4
#  NM               3
#  KS               3
#  ID               2
#  MN               2
#  Los Angeles      1
#  SC               1
#  RI               1
# Name: job_state, dtype: int64

# %%
# If location and headquarters are same make it as 1, else 0
df['same_state'] = df.apply(lambda x: 1 if x.Location==x.Headquarters else 0, axis=1)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Age of the company
df['age'] = df.Founded.apply(lambda x: x if x<1 else 2020-x)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1                  Job Title  \
# 0           0             0             Data Scientist
# 1           1             1  Healthcare Data Scientist
#
#                Salary Estimate  \
# 0   $53K-$91K (Glassdoor est.)
# 1  $63K-$112K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
#
#                                  Company Name         Location   Headquarters  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
#
#                     Size  ...  Competitors hourly employer_provided  \
# 0  501 to 1000 employees  ...           -1      0                 0
# 1       10000+ employees  ...           -1      0                 0
#
# ...

# %%
# Parsing of Job description with data science keywords like: python, spark, r studio, aws, excel

#python
df['python_yn'] = df['Job Description'].apply(lambda x : 1 if 'python' in x.lower() else 0)
df.python_yn.value_counts()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 1    392
# 0    350
# Name: python_yn, dtype: int64

# %%
# R studio
df['R_yn'] = df['Job Description'].apply(lambda x : 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
df.R_yn.value_counts()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0    740
# 1      2
# Name: R_yn, dtype: int64

# %%
# Spark
df['spark'] = df['Job Description'].apply(lambda x : 1 if 'spark' in x.lower() else 0)
df.spark.value_counts()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0    575
# 1    167
# Name: spark, dtype: int64

# %%
# AWS
df['aws'] = df['Job Description'].apply(lambda x : 1 if 'aws' in x.lower() else 0)
df.aws.value_counts()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0    566
# 1    176
# Name: aws, dtype: int64

# %%
# Excel
df['excel'] = df['Job Description'].apply(lambda x : 1 if 'excel' in x.lower() else 0)
df.excel.value_counts()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1    388
# 0    354
# Name: excel, dtype: int64

# %%
# remove first two columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'hourly', 'employer_provided', 'min_salary',
#        'max_salary', 'avg_salary', 'company_txt', 'job_state', 'same_state',
#        'age', 'python_yn', 'R_yn', 'spark', 'aws', 'excel'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.drop(['Unnamed: 0.1'],axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
#
#                                  Company Name         Location   Headquarters  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
#
#                     Size  Founded   Type of ownership  ... avg_salary  \
# 0  501 to 1000 employees     1973   Company - Private  ...       72.0
# 1       10000+ employees     1984  Other Organization  ...       87.5
#
#                                company_txt job_state same_state  age  \
# 0                      Tecolote Research\n        NM          0   47
# ...

# %%
df.to_csv('salary_data_cleaned.csv',index=False)

# %%
pd.read_csv('salary_data_cleaned.csv')
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %%
#### data cleaning
